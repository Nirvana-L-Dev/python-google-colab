# %%
# importing pandas library
import pandas as pd

# %% [markdown]
# **read_csv():** This function is used to read data from a CSV file into a DataFrame.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df =  pd.read_csv('/content/drive/MyDrive/data.csv')

# %% [markdown]
# Display the first 5 rows of the DataFrame

# %%
df.head(10)
# Out:
#          x1        x2    y
# 0  2.483571  1.068200  1.0
# 1 -0.691322 -1.111967  0.0
# 2  3.238443  2.895728  1.0
# 3  7.615149  6.812872  1.0
# 4 -1.170767 -1.332053  0.0
# 5 -1.170685 -0.766634  0.0
# 6  7.896064  9.782250  1.0
# 7  3.837174  4.011751  1.0
# 8 -2.347372 -2.089822  0.0
# 9  2.712800  2.638354  1.0

# %% [markdown]
# Display the last 5 rows of the DataFrame

# %%
df.tail()
# Out:
#           x1        x2    y
# 95 -7.317575 -6.932257  0.0
# 96  1.480601  0.596744  1.0
# 97  1.305276  1.459001  1.0
# 98  0.025567  0.083776  1.0
# 99 -1.172936 -2.315906  0.0

# %% [markdown]
# Display the first 15 rows of the DataFrame

# %%
df.head(15)
# Out:
#           x1        x2    y
# 0   4.489435  5.281626  1.0
# 1   1.174600  0.300846  0.0
# 2   0.296359  0.565397  0.0
# 3  -2.788113 -1.587206  0.0
# 4   5.187258  4.673348  1.0
# 5   5.162665  4.274827  1.0
# 6   5.506976  4.706904  1.0
# 7   0.600883 -1.131641  0.0
# 8   1.042335 -2.104928  0.0
# 9  -1.305786 -0.882829  0.0
# 10 -0.817668 -1.346358  0.0
# 11 -1.019655  0.167942  0.0
# 12  5.131489  3.843291  1.0
# 13  4.699768  4.367739  1.0
# 14  1.175911  0.680072  0.0

# %% [markdown]
# Display the last 15 rows of the DataFrame

# %%
df.tail(15)
# Out:
#            x1        x2    y
# 965  4.583242  6.434887  1.0
# 966  5.143981  5.062360  1.0
# 967  5.181974  5.572843  1.0
# 968  1.162204 -1.097203  0.0
# 969 -2.169408 -0.035605  0.0
# 970 -0.597855 -0.158327  0.0
# 971  0.232650  1.606597  0.0
# 972  1.534090 -0.529914  0.0
# 973  1.929832  0.191482  0.0
# 974  1.523852 -0.683226  0.0
# 975  6.310876  3.509787  1.0
# 976  4.344663  6.511568  1.0
# 977  0.888993  1.161068  0.0
# 978 -0.675469 -0.295829  0.0
# 979 -1.570529 -1.793889  0.0

# %% [markdown]
# **info():** Provides a concise summary of the DataFrame.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      980 non-null    float64
#  1   x2      980 non-null    float64
#  2   y       980 non-null    float64
# dtypes: float64(3)
# memory usage: 23.1 KB
# None

# %% [markdown]
# **describe():** Generates descriptive statistics of numerical columns.

# %%
print(df.describe())
# Out:
#                x1          x2           y
# count  980.000000  980.000000  980.000000
# mean     2.478694    2.485648    0.500000
# std      2.700187    2.700912    0.500255
# min     -3.167055   -3.231055    0.000000
# 25%     -0.029016   -0.039501    0.000000
# 50%      2.212546    2.682945    0.500000
# 75%      5.022171    5.030393    1.000000
# max      7.371388    7.850708    1.000000

# %% [markdown]
# **shape:** Returns dimensions of the DataFrame.

# %%
print(df.shape)
# Out:
# (980, 3)

# %% [markdown]
# **size:** gives the total number of elements in the DataFrame

# %%
print(df.size)
# Out:
# 2940

# %% [markdown]
# **columns:** Returns column labels of the DataFrame.

# %%
print(df.columns)
# Out:
# Index(['x1', 'x2', 'y'], dtype='object')

# %% [markdown]
# **iloc[]:** Integer-location based indexing.

# %%
print(df.iloc[0:2, :])
# Out:
#          x1        x2    y
# 0  4.489435  5.281626  1.0
# 1  1.174600  0.300846  0.0

# %% [markdown]
# **loc[]:** Label-based indexing.

# %%
df.loc[89]
# Out:
# x1    2.566337
# x2    1.051490
# y     1.000000
# Name: 89, dtype: float64

# %% [markdown]
# extract a particular column from a DataFrame

# %%
# single column
df[['x1']]
# Out:
#            x1
# 0    4.489435
# 1    1.174600
# 2    0.296359
# 3   -2.788113
# 4    5.187258
# ..        ...
# 975  6.310876
# 976  4.344663
# 977  0.888993
# 978 -0.675469
# 979 -1.570529
#
# [980 rows x 1 columns]

# %%
## multiple column
df[['x1', 'x2']]
# Out:
#            x1        x2
# 0    4.489435  5.281626
# 1    1.174600  0.300846
# 2    0.296359  0.565397
# 3   -2.788113 -1.587206
# 4    5.187258  4.673348
# ..        ...       ...
# 975  6.310876  3.509787
# 976  4.344663  6.511568
# 977  0.888993  1.161068
# 978 -0.675469 -0.295829
# 979 -1.570529 -1.793889
#
# [980 rows x 2 columns]

# %% [markdown]
# **value_counts():** Count unique values in a Series.

# %%
df['y'].value_counts()
# Out:
# y
# 1.0    490
# 0.0    490
# Name: count, dtype: int64

# %% [markdown]
# **max() and min():** Find the maximum and minimum values in each column.

# %%
print(df.max())
# Out:
# x1    7.371388
# x2    7.850708
# y     1.000000
# dtype: float64

# %%
print(df.min())  #maths #science #Grade(A,B,C)
# Out:
# x1   -3.167055
# x2   -3.231055
# y     0.000000
# dtype: float64

# %% [markdown]
# adding new column to the dataframe

# %%
df['x3'] = df['x1']

# %%
df.head()
# Out:
#          x1        x2    y        x3
# 0  4.489435  5.281626  1.0  4.489435
# 1  1.174600  0.300846  0.0  1.174600
# 2  0.296359  0.565397  0.0  0.296359
# 3 -2.788113 -1.587206  0.0 -2.788113
# 4  5.187258  4.673348  1.0  5.187258

# %% [markdown]
# How to drop any column from dataframe

# %%
df_new = df.drop('y', axis=1)

# %%
df_new.head()
# Out:
#          x1        x2        x3
# 0  4.489435  5.281626  4.489435
# 1  1.174600  0.300846  1.174600
# 2  0.296359  0.565397  0.296359
# 3 -2.788113 -1.587206 -2.788113
# 4  5.187258  4.673348  5.187258

# %% [markdown]
# # Class Work
#
#
# *   Read the given csv file
# *   print first 10 rows
# *   check the number of rows and columns in the csv file
# *   drop the last column and store the rest of the dataframe in one variable called 'X'
# *   store the last column which you droped in another variable called 'Y'
